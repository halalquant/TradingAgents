# %%
from tradingagents.agents.utils.core_crypto_tools import get_crypto_data

# %%
crypto_data = get_crypto_data.invoke({
    "symbol" : "BTC/USDT",
    "start_date" : "2026-01-01",
    "end_date" : "2026-01-18"
})
# Out:
# DEBUG: get_crypto_data - Primary: [bybit] | Full fallback order: [bybit → binance]
# DEBUG: Attempting PRIMARY vendor 'bybit' for get_crypto_data (attempt #1)
# DEBUG: Calling get_market_data from vendor 'bybit'...
# SUCCESS: get_market_data from vendor 'bybit' completed successfully
# SUCCESS: Vendor 'bybit' succeeded - Got 1 result(s)
# DEBUG: Stopping after successful vendor 'bybit' (single-vendor config)
# FINAL: Method 'get_crypto_data' completed with 1 result(s) from 1 vendor attempt(s)

# %%
print(crypto_data)
# Out:
# # Crypto data for BTC/USDT from 2026-01-01 to 2026-01-18
# # Total records: 19
# # Data retrieved on: 2026-01-18 01:44:07 UTC
#
# Date,Open,High,Low,Close,Volume
# 2025-12-31,88499,89217.3,87243.2,87643.3,8091
# 2026-01-01,87643.3,88926.7,87551.7,88848.2,2739
# 2026-01-02,88848.2,90966.2,88377.4,89991.8,9831
# 2026-01-03,89991.8,90749.7,89306.5,90640.4,3836
# 2026-01-04,90640.4,91806.4,90640.4,91531.2,5428
# 2026-01-05,91531.2,94774,91511.1,93862.9,12264
# 2026-01-06,93862.9,94453.7,91272.4,93763.3,11347
# 2026-01-07,93763.3,93763.3,90674.1,91369.9,9962
# 2026-01-08,91369.9,91676.6,89307.5,91104.7,10362
# 2026-01-09,91104.7,92024.5,89696,90643.1,8739
# 2026-01-10,90643.1,90834.5,90395,90514.7,1715
# 2026-01-11,90514.7,91288.9,90234,91004,2911
# 2026-01-12,91004,92529.22,90119.5,91295.1,8955
# 2026-01-13,91295.1,96601.4,91046.1,95412.8,10891
# 2026-01-14,95412.8,97950,94538.1,96950.8,11778
# 2026-01-15,96950.8,97199.9,95125.1,95599.7,9344
# 2026-01-16,95599.7,95855.7,94291.3,95550.6,6415
# 2026-01-17,95550.6,95645.8,95022.6,95144,2107
# 2026-01-18,95144,95238,94868,94995.1,193

# %%
from tradingagents.agents.utils.fundamental_data_tools import get_fundamentals

# %%
fundamentals = get_fundamentals.invoke({
    "ticker" : "BTC/USDT",
    "curr_date" : "2026-01-18"
})
# Out:
# DEBUG: get_fundamentals - Primary: [alpha_vantage] | Full fallback order: [alpha_vantage → openai]
# INFO: Vendor 'alpha_vantage' not supported for method 'get_fundamentals', falling back to next vendor
# DEBUG: Attempting FALLBACK vendor 'openai' for get_fundamentals (attempt #1)
# DEBUG: Calling get_fundamentals_openai from vendor 'openai'...
# SUCCESS: get_fundamentals_openai from vendor 'openai' completed successfully
# SUCCESS: Vendor 'openai' succeeded - Got 1 result(s)
# DEBUG: Stopping after successful vendor 'openai' (single-vendor config)
# FINAL: Method 'get_fundamentals' completed with 1 result(s) from 1 vendor attempt(s)

# %%
print(fundamentals)
# Out:
# As of January 18, 2026, Bitcoin (BTC) is trading at approximately $94,969, reflecting a slight decrease of 0.41% from the previous close. The intraday high reached $95,560, with a low of $94,850.
#
# ## Stock market information for Bitcoin (BTC)
# - Bitcoin is a crypto in the CRYPTO market.
# - The price is 94969.0 USD currently with a change of -391.00 USD (-0.00%) from the previous close.
# - The intraday high is 95560.0 USD and the intraday low is 94850.0 USD.
#
#
# **Purpose and Use Case:**
# Bitcoin serves as a decentralized digital currency, enabling peer-to-peer transactions without the need for intermediaries. Its primary use cases include acting as a store of value, a medium of exchange, and a hedge against inflation.
#
# **Technology:**
# Bitcoin operates on a proof-of-work (PoW) consensus mechanism, utilizing a decentralized network of miners to validate transactions and secure the blockchain. The network's security and integrity are maintained through cryptographic techniques and a transparent ledger.
#
# **Token Utility and Tokenomics:**
# Bitcoin's native token, BTC, is used to pay for transaction fees and as an incentive for miners. The total supply is capped at 21 million coins, introducing scarcity and potentially increasing value over time. As of January 18, 2026, approximately 19 million BTC have been mined, with the remaining supply expected to be mined over the next century.
#
# **Team and Organization:**
# Bitcoin was introduced in 2008 by an anonymous entity known as Satoshi Nakamoto. Since then, it has been maintained by a decentralized group of developers and contributors worldwide, without a central governing body.
#
# **Development Activity:**
# Development on the Bitcoin network is ongoing, with regular updates and improvements proposed and implemented by the community. The network's open-source nature allows for continuous innovation and adaptation to emerging challenges.
#
# **Ecosystem and Adoption:**
# Bitcoin has seen widespread adoption, with numerous businesses accepting it as payment and financial institutions integrating it into their services. The ecosystem includes exchanges, wallets, and various financial products, contributing to its growing acceptance and use.
#
# **Governance and Community:**
# Bitcoin's governance is decentralized, with decisions made through community consensus. Proposals for changes or upgrades are discussed and debated within the community, ensuring that no single entity has control over the network.
#
# Please note that cryptocurrency markets are highly volatile, and the information provided is subject to rapid changes.

# %%
from tradingagents.agents.utils.fundamental_data_tools import get_whitepaper

# %%
whitepaper = get_whitepaper.invoke({
    "ticker" : "BTC/USDT",
})
# Out:
# DEBUG: get_whitepaper - Primary: [alpha_vantage] | Full fallback order: [alpha_vantage → openai]
# INFO: Vendor 'alpha_vantage' not supported for method 'get_whitepaper', falling back to next vendor
# DEBUG: Attempting FALLBACK vendor 'openai' for get_whitepaper (attempt #1)
# DEBUG: Calling get_whitepaper_openai from vendor 'openai'...
# SUCCESS: get_whitepaper_openai from vendor 'openai' completed successfully
# SUCCESS: Vendor 'openai' succeeded - Got 1 result(s)
# DEBUG: Stopping after successful vendor 'openai' (single-vendor config)
# FINAL: Method 'get_whitepaper' completed with 1 result(s) from 1 vendor attempt(s)

# %%
print(whitepaper)
# Out:
# Bitcoin (BTC) and Tether (USDT) are two prominent cryptocurrencies, each with distinct white papers outlining their foundational principles and operational mechanisms.
#
# **Bitcoin (BTC) White Paper:**
#
# Published on October 31, 2008, by the pseudonymous Satoshi Nakamoto, the Bitcoin white paper titled "Bitcoin: A Peer-to-Peer Electronic Cash System" introduces a decentralized digital currency system. The key objectives outlined include:
#
# - **Decentralization:** Eliminating the need for a central authority by enabling peer-to-peer transactions.
# - **Security:** Utilizing cryptographic techniques to secure transactions and control the creation of new units.
# - **Transparency:** Implementing a public ledger (blockchain) to record all transactions, ensuring transparency and immutability.
#
# This white paper laid the groundwork for the development of Bitcoin, which has since become a leading digital asset in the cryptocurrency market. ([kucoin.com](https://www.kucoin.com/th/news/flash/bitcoin-white-paper-released-17-years-ago-on-october-31-2008?utm_source=openai))
#
# **Tether (USDT) White Paper:**
#
# Tether (USDT) is a stablecoin introduced by Tether Limited in 2014, designed to maintain a 1:1 peg with the U.S. dollar. The white paper for Tether outlines:
#
# - **Stability:** Ensuring that each USDT token is backed by a corresponding U.S. dollar, providing price stability.
# - **Transparency:** Regular audits and disclosures to verify the reserves backing USDT.
# - **Efficiency:** Facilitating faster and more cost-effective transactions compared to traditional banking systems.
#
# Tether has become a widely used stablecoin in the cryptocurrency ecosystem, offering a stable medium of exchange and store of value. ([en.wikipedia.org](https://en.wikipedia.org/wiki/Tether_%28cryptocurrency%29?utm_source=openai))
#
# Both white papers have significantly influenced the cryptocurrency landscape, with Bitcoin pioneering decentralized digital currencies and Tether providing a stablecoin solution to mitigate the volatility inherent in other cryptocurrencies.

# %%
from tradingagents.agents.utils.fundamental_data_tools import get_market_cap

# %%
market_cap = get_market_cap.invoke({
})
# Out:
# DEBUG: get_market_cap - Primary: [alpha_vantage] | Full fallback order: [alpha_vantage → coin_gecko]
# INFO: Vendor 'alpha_vantage' not supported for method 'get_market_cap', falling back to next vendor
# DEBUG: Attempting FALLBACK vendor 'coin_gecko' for get_market_cap (attempt #1)
# DEBUG: Calling get_market_cap from vendor 'coin_gecko'...
# DEBUG: CoinGecko API response status code: 200
# SUCCESS: get_market_cap from vendor 'coin_gecko' completed successfully
# SUCCESS: Vendor 'coin_gecko' succeeded - Got 1 result(s)
# DEBUG: Stopping after successful vendor 'coin_gecko' (single-vendor config)
# FINAL: Method 'get_market_cap' completed with 1 result(s) from 1 vendor attempt(s)

# %%
print(market_cap)
# Out:
# # Market Capitalization Percentage Data
#
# - BTC: 57.36%
# - ETH: 12.04%
# - USDT: 5.65%
# - BNB: 3.89%
# - XRP: 3.78%
# - SOL: 2.44%
# - USDC: 2.30%
# - TRX: 0.91%
# - STETH: 0.90%
# - DOGE: 0.70%

# %%
from tradingagents.agents.utils.news_data_tools import get_news

# %%
news = get_news.invoke({
    "ticker" : "BTC/USDT",
    "start_date" : "2026-01-01",
    "end_date" : "2026-01-18"
})
# Out:
# DEBUG: get_news - Primary: [openai] | Full fallback order: [openai → alpha_vantage → google]
# DEBUG: Attempting PRIMARY vendor 'openai' for get_news (attempt #1)
# DEBUG: Calling get_crypto_news_openai from vendor 'openai'...
# SUCCESS: get_crypto_news_openai from vendor 'openai' completed successfully
# SUCCESS: Vendor 'openai' succeeded - Got 1 result(s)
# DEBUG: Stopping after successful vendor 'openai' (single-vendor config)
# FINAL: Method 'get_news' completed with 1 result(s) from 1 vendor attempt(s)

# %%
print(news)
# Out:
# Between January 1 and January 18, 2026, several notable developments occurred in the Bitcoin (BTC) and Tether (USDT) markets:
#
# **Price Movements:**
#
# - **January 1, 2026:** Bitcoin opened the year at $88,722.07, marking a 1.4% increase for the day. ([statmuse.com](https://www.statmuse.com/money/ask/btc-usd-price-january-1st-2026?utm_source=openai))
#
# - **January 9, 2026:** Bitcoin's price experienced a slight decline, closing at $90,290.80, down 0.84% from the previous day. ([bestcryptochecker.com](https://bestcryptochecker.com/coin/btc/price-history/2026/1?utm_source=openai))
#
# **Market Forecasts:**
#
# - Analysts projected a bullish trend for January 2026, with expectations of Bitcoin reaching between $98,000 and $105,000, driven by strong ETF flows and increased institutional adoption. ([vtrader.io](https://www.vtrader.io/news/bitcoin-price-prediction-january-2026-new-year-forecast/?utm_source=openai))
#
# **Exchange Reserves:**
#
# - Binance reported that its BTC reserve rate stood at 100.06%, and USDT reserves at 101.69%, indicating that user deposits were fully backed by reserves. ([ainvest.com](https://www.ainvest.com/news/binance-update-btc-reserve-rate-100-06-usdt-101-69-2601/?utm_source=openai))
#
# **Regulatory Developments:**
#
# - On January 1, 2026, Turkmenistan legalized cryptocurrency mining and exchanges, marking a significant policy shift in the region. ([en.wikipedia.org](https://en.wikipedia.org/wiki/2026_in_Turkmenistan?utm_source=openai))
#
# These events reflect the dynamic nature of the cryptocurrency market during this period.
#
# ## Stock market information for Bitcoin (BTC)
# - Bitcoin is a crypto in the CRYPTO market.
# - The price is 94866.0 USD currently with a change of -418.00 USD (-0.00%) from the previous close.
# - The intraday high is 95560.0 USD and the intraday low is 94850.0 USD.

# %%
from tradingagents.dataflows.local import get_fear_and_greed
# Out:
# INFO: Loading environment from /home/aidev6/Documents/Projects/trading/TradingAgents/.env

# %%
print(get_fear_and_greed(5, "2026-01-16"))
# Out:
# ## Fear and Greed Index Data:
#
# ### Date: 2026-01-16
# Fear and Greed Index: 49
# Classification: Neutral
#
# ### Date: 2026-01-15
# Fear and Greed Index: 61
# Classification: Greed
#
# ### Date: 2026-01-14
# Fear and Greed Index: 48
# Classification: Neutral
#
# ### Date: 2026-01-13
# Fear and Greed Index: 26
# Classification: Fear
#
# ### Date: 2026-01-12
# Fear and Greed Index: 27
# Classification: Fear
#
# ### Date: 2026-01-11
# Fear and Greed Index: 29
# Classification: Fear

# %%
print(get_fear_and_greed(5, "2025-11-16"))
